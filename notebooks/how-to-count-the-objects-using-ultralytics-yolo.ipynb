# %% [markdown]
# <div align="center">
#
#   <a href="https://ultralytics.com/yolo" target="_blank">
#     <img width="1024", src="https://raw.githubusercontent.com/ultralytics/assets/main/yolov8/banner-yolov8.png"></a>
#
#   [中文](https://docs.ultralytics.com/zh/) | [한국어](https://docs.ultralytics.com/ko/) | [日本語](https://docs.ultralytics.com/ja/) | [Русский](https://docs.ultralytics.com/ru/) | [Deutsch](https://docs.ultralytics.com/de/) | [Français](https://docs.ultralytics.com/fr/) | [Español](https://docs.ultralytics.com/es/) | [Português](https://docs.ultralytics.com/pt/) | [Türkçe](https://docs.ultralytics.com/tr/) | [Tiếng Việt](https://docs.ultralytics.com/vi/) | [العربية](https://docs.ultralytics.com/ar/)
#
#   <a href="https://github.com/ultralytics/ultralytics/actions/workflows/ci.yml"><img src="https://github.com/ultralytics/ultralytics/actions/workflows/ci.yml/badge.svg" alt="Ultralytics CI"></a>
#   <a href="https://colab.research.google.com/github/ultralytics/notebooks/blob/main/notebooks/how-to-count-the-objects-using-ultralytics-yolo.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"></a>
#
#   <a href="https://ultralytics.com/discord"><img alt="Discord" src="https://img.shields.io/discord/1089800235347353640?logo=discord&logoColor=white&label=Discord&color=blue"></a>
#   <a href="https://community.ultralytics.com"><img alt="Ultralytics Forums" src="https://img.shields.io/discourse/users?server=https%3A%2F%2Fcommunity.ultralytics.com&logo=discourse&label=Forums&color=blue"></a>
#   <a href="https://reddit.com/r/ultralytics"><img alt="Ultralytics Reddit" src="https://img.shields.io/reddit/subreddit-subscribers/ultralytics?style=flat&logo=reddit&logoColor=white&label=Reddit&color=blue"></a>
#
#   Welcome to the Object counting using Ultralytics YOLO11 🚀 notebook! <a href="https://github.com/ultralytics/ultralytics">YOLO11</a> is the latest version of the YOLO (You Only Look Once) AI models developed by <a href="https://ultralytics.com">Ultralytics</a>. We hope that the resources in this notebook will help you get the most out of YOLO11. Please browse the YOLO11 <a href="https://docs.ultralytics.com/">Docs</a> for details, raise an issue on <a href="https://github.com/ultralytics/ultralytics">GitHub</a> for support, and join our <a href="https://ultralytics.com/discord">Discord</a> community for questions and discussions!</div>

# %% [markdown]
# # Object Counting using Ultralytics YOLO11
#
# This notebook serves as a starting point for [counting objects](https://docs.ultralytics.com/guides/object-counting/) in videos or live streams using the YOLO11 model.
#
# ### What is Object Counting?
#
# - Object counting with YOLO11 involves accurate identification and counting of specific objects in videos and camera streams. YOLO11 excels in real-time applications, providing efficient and precise object counting for various scenarios like crowd analysis and surveillance, thanks to its state-of-the-art algorithms and deep learning capabilities.
#
# ### Advantages of Object Counting?
#
# - **Resource Optimization**: Object counting facilitates efficient resource management by providing accurate counts, and optimizing resource allocation in applications like inventory management.
# - **Enhanced Security**: Object counting enhances security and surveillance by accurately tracking and counting entities, aiding in proactive threat detection.
# - **Informed Decision-Making**: Object counting offers valuable insights for decision-making, optimizing processes in retail, traffic management, and various other domains.

# %% [markdown]
# ### Setup
#
# pip install `ultralytics` and [dependencies](https://github.com/ultralytics/ultralytics/blob/main/pyproject.toml) and check software and hardware.
#
# [![PyPI - Version](https://img.shields.io/pypi/v/ultralytics?logo=pypi&logoColor=white)](https://pypi.org/project/ultralytics/) [![Downloads](https://static.pepy.tech/badge/ultralytics)](https://clickpy.clickhouse.com/dashboard/ultralytics) [![PyPI - Python Version](https://img.shields.io/pypi/pyversions/ultralytics?logo=python&logoColor=gold)](https://pypi.org/project/ultralytics/)

# %%
# !uv pip install ultralytics

import ultralytics
import cv2
from ultralytics.utils.downloads import safe_download
from ultralytics import solutions

ultralytics.checks()
# Out:
# Ultralytics 8.3.232 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 38.1/235.7 GB disk)

# %% [markdown]
# ### Read the Video File
#
# - You can either read the video file directly or stream the content from an RTSP (Real-Time Streaming Protocol) source, allowing for flexible video input depending on your needs.
# - We will also set up the video writer to handle the output video writing.

# %%
safe_download("https://github.com/ultralytics/notebooks/releases/download/v0.0.0/solutions-ci-demo.mp4")
cap = cv2.VideoCapture("/content/3669014919-preview.mp4")
assert cap.isOpened(), "Error reading video file"
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH,
                                       cv2.CAP_PROP_FRAME_HEIGHT,
                                       cv2.CAP_PROP_FPS))

# Video writer
video_writer = cv2.VideoWriter("counting.avi",
                               cv2.VideoWriter_fourcc(*"mp4v"),
                               fps, (w, h))
# Out:
# Downloading https://github.com/ultralytics/notebooks/releases/download/v0.0.0/solutions-ci-demo.mp4 to 'solutions-ci-demo.mp4': 100% ━━━━━━━━━━━━ 264.6KB 14.9MB/s 0.0s

# %% [markdown]
# ### Define Region Coordinates
#
# Here, we set the coordinates for specific regions to ensure accurate object tracking and analysis within the video or stream. This helps monitor and count objects effectively in different areas.

# %%
# Define region points
# region_points = [(20, 400), (1080, 400)]  # For line counting
region_points = [(20, 400), (1080, 400), (1080, 360), (20, 360)]  # For rectangle region counting
# region_points = [(20, 400), (1080, 400), (1080, 360), (20, 360), (20, 400)]  # For polygon region counting

# %% [markdown]
# ### Initialize the ObjectCounter Class
#
# - Now, let's initialize the `ObjectCounter` class to track and count objects in each frame of the video.

# %%
# Init ObjectCounter
counter = solutions.ObjectCounter(
    show=True,  # Display the output
    region=region_points,  # Pass region points
    model="yolo11n.pt",  # model="yolo11n-obb.pt" for object counting using YOLO11 OBB model.
    # classes=[0, 2],  # If you want to count specific classes i.e person and car with COCO pretrained model.
    # show_in=True,  # Display in counts
    # show_out=True,  # Display out counts
    # line_width=2,  # Adjust the line width for bounding boxes and text display
)
# Out:
# Ultralytics Solutions: ✅ {'source': None, 'model': 'yolo11n.pt', 'classes': None, 'show_conf': True, 'show_labels': True, 'region': [(20, 400), (1080, 400), (1080, 360), (20, 360)], 'colormap': 21, 'show_in': True, 'show_out': True, 'up_angle': 145.0, 'down_angle': 90, 'kpts': [6, 8, 10], 'analytics_type': 'line', 'figsize': (12.8, 7.2), 'blur_ratio': 0.5, 'vision_point': (20, 20), 'crop_dir': 'cropped-detections', 'json_file': None, 'line_width': 2, 'records': 5, 'fps': 30.0, 'max_hist': 5, 'meter_per_pixel': 0.05, 'max_speed': 120, 'show': True, 'iou': 0.7, 'conf': 0.25, 'device': None, 'max_det': 300, 'half': False, 'tracker': 'botsort.yaml', 'verbose': True, 'data': 'images'}
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()

# %% [markdown]
# ### Process Video Frames
#
# In this step, we will process each frame of the video to detect and analyze objects. This allows for real-time tracking and counting, based on the visual data in the frames.

# %%
from google.colab.patches import cv2_imshow

# %%
# Process video
first_frame = None
last_frame = None

while cap.isOpened():
    success, im0 = cap.read()
    if not success:
        print("Video frame is empty or video processing has been successfully completed.")
        break
    results = counter(im0)  # count the objects
    video_writer.write(results.plot_im)   # write the video frames

    # Store the first frame
    if first_frame is None:
        first_frame = results.plot_im

    # Always update last_frame
    last_frame = results.plot_im

cap.release()   # Release the capture
video_writer.release()

# Show the first output
cv2_imshow(first_frame)
cv2.waitKey(0)  # Wait for a key press
cv2.destroyAllWindows()

# Show the last output
cv2_imshow(last_frame)
cv2.waitKey(0)  # Wait for a key press
cv2.destroyAllWindows()
# Out:
# 0: 506x898 2.7ms, 1 keyboard, 8 donut
# Speed: 73.4ms track, 2.7ms solution per image at shape (1, 3, 506, 898)
#
# 1: 506x898 4.4ms, 7 donut
# Speed: 49.5ms track, 4.4ms solution per image at shape (1, 3, 506, 898)
#
# 2: 506x898 2.2ms, 8 donut
# Speed: 32.9ms track, 2.2ms solution per image at shape (1, 3, 506, 898)
#
# 3: 506x898 1.8ms, 10 donut
# Speed: 32.0ms track, 1.8ms solution per image at shape (1, 3, 506, 898)
#
# 4: 506x898 1.8ms, 9 donut
# Speed: 32.0ms track, 1.8ms solution per image at shape (1, 3, 506, 898)
#
# 5: 506x898 1.5ms, 7 donut
# Speed: 33.3ms track, 1.5ms solution per image at shape (1, 3, 506, 898)
#
# 6: 506x898 1.8ms, 8 donut
# Speed: 33.2ms track, 1.8ms solution per image at shape (1, 3, 506, 898)
#
# 7: 506x898 1.8ms, 9 donut
# Speed: 32.1ms track, 1.8ms solution per image at shape (1, 3, 506, 898)
#
# 8: 506x898 1.7ms, 8 donut
# Speed: 31.4ms track, 1.7ms solution per image at shape (1, 3, 506, 898)
#
# 9: 506x898 1.8ms, 9 donut
# Speed: 31.6ms track, 1.8ms solution per image at shape (1, 3, 506, 898)
#
# 10: 506x898 1.7ms, 8 donut
# Speed: 32.9ms track, 1.7ms solution per image at shape (1, 3, 506, 898)
#
# 11: 506x898 1.6ms, 8 donut
# Speed: 31.8ms track, 1.6ms solution per image at shape (1, 3, 506, 898)
#
# 12: 506x898 1.9ms, 9 donut
# Speed: 32.2ms track, 1.9ms solution per image at shape (1, 3, 506, 898)
#
# 13: 506x898 1.9ms, 10 donut
# Speed: 31.5ms track, 1.9ms solution per image at shape (1, 3, 506, 898)
#
# 14: 506x898 2.5ms, 10 donut
# Speed: 35.7ms track, 2.5ms solution per image at shape (1, 3, 506, 898)
#
# 15: 506x898 2.2ms, 10 donut
# Speed: 34.6ms track, 2.2ms solution per image at shape (1, 3, 506, 898)
#
# 16: 506x898 2.4ms, 11 donut
# Speed: 33.3ms track, 2.4ms solution per image at shape (1, 3, 506, 898)
#
# 17: 506x898 2.3ms, 12 donut
# Speed: 34.3ms track, 2.3ms solution per image at shape (1, 3, 506, 898)
#
# 18: 506x898 2.5ms, 13 donut
# Speed: 34.6ms track, 2.5ms solution per image at shape (1, 3, 506, 898)
#
# 19: 506x898 2.3ms, 12 donut
# Speed: 32.8ms track, 2.3ms solution per image at shape (1, 3, 506, 898)
#
# 20: 506x898 2.6ms, 13 donut
# Speed: 33.2ms track, 2.6ms solution per image at shape (1, 3, 506, 898)
#
# 21: 506x898 2.5ms, 13 donut
# Speed: 45.3ms track, 2.5ms solution per image at shape (1, 3, 506, 898)
#
# 22: 506x898 2.4ms, 13 donut
# Speed: 33.0ms track, 2.4ms solution per image at shape (1, 3, 506, 898)
#
# 23: 506x898 2.4ms, 12 donut
# Speed: 33.5ms track, 2.4ms solution per image at shape (1, 3, 506, 898)
#
# 24: 506x898 2.0ms, 6 donut, 3 cake
# Speed: 34.6ms track, 2.0ms solution per image at shape (1, 3, 506, 898)
#
# 25: 506x898 3.0ms, 8 donut
# Speed: 37.7ms track, 3.0ms solution per image at shape (1, 3, 506, 898)
#
# 26: 506x898 7.8ms, 10 donut
# Speed: 93.7ms track, 7.8ms solution per image at shape (1, 3, 506, 898)
#
# 27: 506x898 2.5ms, 8 donut
# Speed: 73.2ms track, 2.5ms solution per image at shape (1, 3, 506, 898)
#
# 28: 506x898 4.9ms, 8 donut
# Speed: 138.9ms track, 4.9ms solution per image at shape (1, 3, 506, 898)
#
# 29: 506x898 2.1ms, 2 donut, 2 cake
# Speed: 108.5ms track, 2.1ms solution per image at shape (1, 3, 506, 898)
#
# 30: 506x898 2.1ms, 5 donut, 2 cake
# Speed: 56.9ms track, 2.1ms solution per image at shape (1, 3, 506, 898)
#
# 31: 506x898 1.9ms, 4 donut, 2 cake
# Speed: 59.2ms track, 1.9ms solution per image at shape (1, 3, 506, 898)
#
# 32: 506x898 4.6ms, 7 cake, 1 donut
# Speed: 71.4ms track, 4.6ms solution per image at shape (1, 3, 506, 898)
#
# 33: 506x898 5.4ms, 3 donut, 5 cake
# Speed: 84.7ms track, 5.4ms solution per image at shape (1, 3, 506, 898)
#
# 34: 506x898 6.6ms, 7 cake, 1 donut
# Speed: 141.0ms track, 6.6ms solution per image at shape (1, 3, 506, 898)
#
# 35: 506x898 2.4ms, 7 cake
# Speed: 89.8ms track, 2.4ms solution per image at shape (1, 3, 506, 898)
#
# 36: 506x898 2.2ms, 6 cake, 1 donut
# Speed: 74.6ms track, 2.2ms solution per image at shape (1, 3, 506, 898)
#
# 37: 506x898 3.9ms, 5 cake
# Speed: 79.1ms track, 3.9ms solution per image at shape (1, 3, 506, 898)
#
# 38: 506x898 1.6ms, 5 cake
# Speed: 78.6ms track, 1.6ms solution per image at shape (1, 3, 506, 898)
#
# 39: 506x898 2.3ms, 5 cake, 1 donut
# Speed: 66.8ms track, 2.3ms solution per image at shape (1, 3, 506, 898)
#
# 40: 506x898 2.3ms, 2 cake, 4 donut
# Speed: 86.2ms track, 2.3ms solution per image at shape (1, 3, 506, 898)
#
# 41: 506x898 2.9ms, 9 donut
# Speed: 111.6ms track, 2.9ms solution per image at shape (1, 3, 506, 898)
#
# 42: 506x898 2.4ms, 1 cake, 6 donut, 1 keyboard
# Speed: 62.8ms track, 2.4ms solution per image at shape (1, 3, 506, 898)
#
# 43: 506x898 2.5ms, 5 donut, 1 keyboard
# Speed: 53.0ms track, 2.5ms solution per image at shape (1, 3, 506, 898)
#
# 44: 506x898 2.3ms, 4 donut, 1 keyboard
# Speed: 64.2ms track, 2.3ms solution per image at shape (1, 3, 506, 898)
#
# 45: 506x898 1.8ms, 5 donut
# Speed: 50.1ms track, 1.8ms solution per image at shape (1, 3, 506, 898)
#
# 46: 506x898 2.3ms, 5 donut, 1 keyboard
# Speed: 49.9ms track, 2.3ms solution per image at shape (1, 3, 506, 898)
#
# 47: 506x898 1.8ms, 4 donut, 1 keyboard
# Speed: 49.3ms track, 1.8ms solution per image at shape (1, 3, 506, 898)
#
# 48: 506x898 2.1ms, 4 donut, 1 keyboard, 1 cake
# Speed: 54.8ms track, 2.1ms solution per image at shape (1, 3, 506, 898)
#
# 49: 506x898 1.8ms, 4 donut, 1 cake
# Speed: 54.0ms track, 1.8ms solution per image at shape (1, 3, 506, 898)
#
# 50: 506x898 1.8ms, 4 donut, 1 cake
# Speed: 52.8ms track, 1.8ms solution per image at shape (1, 3, 506, 898)
#
# 51: 506x898 1.0ms, 1 donut, 1 cake
# Speed: 51.2ms track, 1.0ms solution per image at shape (1, 3, 506, 898)
#
# 52: 506x898 1.7ms, 3 donut, 1 keyboard
# Speed: 50.5ms track, 1.7ms solution per image at shape (1, 3, 506, 898)
#
# 53: 506x898 2.0ms, 4 donut, 1 keyboard
# Speed: 51.2ms track, 2.0ms solution per image at shape (1, 3, 506, 898)
#
# 54: 506x898 1.9ms, 4 donut, 1 keyboard
# Speed: 50.7ms track, 1.9ms solution per image at shape (1, 3, 506, 898)
#
# 55: 506x898 1.9ms, 4 donut, 1 keyboard
# Speed: 49.8ms track, 1.9ms solution per image at shape (1, 3, 506, 898)
#
# 56: 506x898 1.5ms, 4 donut
# Speed: 51.3ms track, 1.5ms solution per image at shape (1, 3, 506, 898)
#
# 57: 506x898 1.8ms, 4 donut, 1 keyboard
# Speed: 52.9ms track, 1.8ms solution per image at shape (1, 3, 506, 898)
#
# 58: 506x898 1.7ms, 4 donut, 1 keyboard
# Speed: 49.8ms track, 1.7ms solution per image at shape (1, 3, 506, 898)
#
# 59: 506x898 1.7ms, 4 donut, 1 keyboard
# Speed: 49.0ms track, 1.7ms solution per image at shape (1, 3, 506, 898)
#
# 60: 506x898 2.0ms, 5 donut, 1 keyboard
# Speed: 49.8ms track, 2.0ms solution per image at shape (1, 3, 506, 898)
#
# 61: 506x898 1.9ms, 5 donut
# Speed: 55.8ms track, 1.9ms solution per image at shape (1, 3, 506, 898)
#
# 62: 506x898 1.5ms, 4 donut
# Speed: 52.6ms track, 1.5ms solution per image at shape (1, 3, 506, 898)
#
# 63: 506x898 1.6ms, 3 donut, 1 keyboard
# Speed: 50.9ms track, 1.6ms solution per image at shape (1, 3, 506, 898)
#
# 64: 506x898 1.3ms, 2 donut, 1 keyboard
# Speed: 51.0ms track, 1.3ms solution per image at shape (1, 3, 506, 898)
#
# 65: 506x898 1.9ms, 4 donut
# Speed: 60.8ms track, 1.9ms solution per image at shape (1, 3, 506, 898)
#
# 66: 506x898 1.3ms, 3 donut
# Speed: 49.9ms track, 1.3ms solution per image at shape (1, 3, 506, 898)
#
# 67: 506x898 1.3ms, 3 donut
# Speed: 52.6ms track, 1.3ms solution per image at shape (1, 3, 506, 898)
#
# 68: 506x898 0.8ms, 1 cake
# Speed: 53.0ms track, 0.8ms solution per image at shape (1, 3, 506, 898)
#
# 69: 506x898 1.4ms, 3 donut
# Speed: 56.3ms track, 1.4ms solution per image at shape (1, 3, 506, 898)
#
# 70: 506x898 1.7ms, 3 donut
# Speed: 58.9ms track, 1.7ms solution per image at shape (1, 3, 506, 898)
#
# 71: 506x898 2.2ms, 5 donut
# Speed: 56.2ms track, 2.2ms solution per image at shape (1, 3, 506, 898)
#
# 72: 506x898 2.2ms, 5 donut
# Speed: 57.5ms track, 2.2ms solution per image at shape (1, 3, 506, 898)
#
# 73: 506x898 2.7ms, 7 donut
# Speed: 55.2ms track, 2.7ms solution per image at shape (1, 3, 506, 898)
#
# 74: 506x898 3.4ms, 9 donut
# Speed: 55.5ms track, 3.4ms solution per image at shape (1, 3, 506, 898)
#
# 75: 506x898 2.0ms, 10 donut
# Speed: 34.7ms track, 2.0ms solution per image at shape (1, 3, 506, 898)
#
# 76: 506x898 2.4ms, 11 donut, 1 keyboard
# Speed: 32.8ms track, 2.4ms solution per image at shape (1, 3, 506, 898)
#
# 77: 506x898 2.3ms, 10 donut, 1 keyboard
# Speed: 32.5ms track, 2.3ms solution per image at shape (1, 3, 506, 898)
#
# 78: 506x898 3.2ms, 9 donut
# Speed: 35.9ms track, 3.2ms solution per image at shape (1, 3, 506, 898)
#
# 79: 506x898 1.5ms, 5 donut, 1 keyboard
# Speed: 38.0ms track, 1.5ms solution per image at shape (1, 3, 506, 898)
#
# 80: 506x898 1.6ms, 6 donut, 1 keyboard
# Speed: 32.8ms track, 1.6ms solution per image at shape (1, 3, 506, 898)
#
# 81: 506x898 1.4ms, 6 donut
# Speed: 32.8ms track, 1.4ms solution per image at shape (1, 3, 506, 898)
#
# 82: 506x898 1.9ms, 8 donut
# Speed: 32.1ms track, 1.9ms solution per image at shape (1, 3, 506, 898)
#
# 83: 506x898 2.2ms, 9 donut
# Speed: 33.9ms track, 2.2ms solution per image at shape (1, 3, 506, 898)
#
# 84: 506x898 1.4ms, 7 donut
# Speed: 32.2ms track, 1.4ms solution per image at shape (1, 3, 506, 898)
#
# 85: 506x898 1.0ms, 4 donut
# Speed: 31.4ms track, 1.0ms solution per image at shape (1, 3, 506, 898)
#
# 86: 506x898 0.7ms, 2 donut
# Speed: 32.1ms track, 0.7ms solution per image at shape (1, 3, 506, 898)
#
# 87: 506x898 1.1ms, 4 donut
# Speed: 32.2ms track, 1.1ms solution per image at shape (1, 3, 506, 898)
#
# 88: 506x898 1.3ms, 5 donut, 1 cake
# Speed: 31.2ms track, 1.3ms solution per image at shape (1, 3, 506, 898)
#
# 89: 506x898 0.8ms, 1 donut, 1 cake
# Speed: 33.0ms track, 0.8ms solution per image at shape (1, 3, 506, 898)
#
# 90: 506x898 0.7ms, 2 cake
# Speed: 32.2ms track, 0.7ms solution per image at shape (1, 3, 506, 898)
#
# 91: 506x898 0.7ms, 2 cake
# Speed: 36.1ms track, 0.7ms solution per image at shape (1, 3, 506, 898)
#
# 92: 506x898 0.5ms, 1 donut
# Speed: 31.8ms track, 0.5ms solution per image at shape (1, 3, 506, 898)
#
# 93: 506x898 0.6ms, 1 donut
# Speed: 32.4ms track, 0.6ms solution per image at shape (1, 3, 506, 898)
#
# WARNING ⚠️ no tracks found!
# 94: 506x898 1.2ms,
# Speed: 32.3ms track, 1.2ms solution per image at shape (1, 3, 506, 898)
#
# 95: 506x898 0.8ms, 1 keyboard, 1 donut
# Speed: 33.9ms track, 0.8ms solution per image at shape (1, 3, 506, 898)
#
# 96: 506x898 1.2ms, 1 keyboard, 3 donut
# Speed: 32.8ms track, 1.2ms solution per image at shape (1, 3, 506, 898)
#
# 97: 506x898 1.1ms, 1 keyboard, 3 donut
# Speed: 32.7ms track, 1.1ms solution per image at shape (1, 3, 506, 898)
#
# 98: 506x898 0.9ms, 3 donut
# Speed: 33.8ms track, 0.9ms solution per image at shape (1, 3, 506, 898)
#
# 99: 506x898 1.2ms, 4 donut
# Speed: 32.6ms track, 1.2ms solution per image at shape (1, 3, 506, 898)
#
# 100: 506x898 1.0ms, 3 donut
# Speed: 32.8ms track, 1.0ms solution per image at shape (1, 3, 506, 898)
#
# 101: 506x898 1.6ms, 3 donut, 1 cake, 1 keyboard
# Speed: 32.8ms track, 1.6ms solution per image at shape (1, 3, 506, 898)
#
# 102: 506x898 1.2ms, 5 donut
# Speed: 32.6ms track, 1.2ms solution per image at shape (1, 3, 506, 898)
#
# 103: 506x898 1.6ms, 7 donut
# Speed: 32.3ms track, 1.6ms solution per image at shape (1, 3, 506, 898)
#
# 104: 506x898 1.2ms, 4 donut
# Speed: 45.9ms track, 1.2ms solution per image at shape (1, 3, 506, 898)
#
# 105: 506x898 0.9ms, 3 donut
# Speed: 33.3ms track, 0.9ms solution per image at shape (1, 3, 506, 898)
#
# 106: 506x898 1.7ms, 7 donut, 1 keyboard
# Speed: 33.3ms track, 1.7ms solution per image at shape (1, 3, 506, 898)
#
# 107: 506x898 2.4ms, 8 donut, 1 keyboard
# Speed: 33.5ms track, 2.4ms solution per image at shape (1, 3, 506, 898)
#
# 108: 506x898 1.8ms, 8 donut, 1 keyboard
# Speed: 33.1ms track, 1.8ms solution per image at shape (1, 3, 506, 898)
#
# 109: 506x898 1.3ms, 6 donut
# Speed: 31.9ms track, 1.3ms solution per image at shape (1, 3, 506, 898)
#
# 110: 506x898 1.9ms, 9 donut
# Speed: 31.6ms track, 1.9ms solution per image at shape (1, 3, 506, 898)
#
# 111: 506x898 1.5ms, 7 donut
# Speed: 32.4ms track, 1.5ms solution per image at shape (1, 3, 506, 898)
#
# 112: 506x898 1.6ms, 8 donut
# Speed: 33.7ms track, 1.6ms solution per image at shape (1, 3, 506, 898)
#
# 113: 506x898 1.7ms, 8 donut
# Speed: 31.7ms track, 1.7ms solution per image at shape (1, 3, 506, 898)
#
# 114: 506x898 2.2ms, 8 donut
# Speed: 34.1ms track, 2.2ms solution per image at shape (1, 3, 506, 898)
#
# 115: 506x898 2.2ms, 8 donut
# Speed: 35.4ms track, 2.2ms solution per image at shape (1, 3, 506, 898)
#
# 116: 506x898 1.2ms, 4 donut, 1 keyboard
# Speed: 32.8ms track, 1.2ms solution per image at shape (1, 3, 506, 898)
#
# 117: 506x898 1.0ms, 2 donut, 1 keyboard
# Speed: 31.7ms track, 1.0ms solution per image at shape (1, 3, 506, 898)
#
# 118: 506x898 1.1ms, 3 donut, 1 keyboard
# Speed: 32.9ms track, 1.1ms solution per image at shape (1, 3, 506, 898)
#
# 119: 506x898 0.9ms, 1 keyboard
# Speed: 32.4ms track, 0.9ms solution per image at shape (1, 3, 506, 898)
#
# 120: 506x898 0.8ms, 1 keyboard, 1 donut
# Speed: 35.5ms track, 0.8ms solution per image at shape (1, 3, 506, 898)
#
# 121: 506x898 0.7ms, 1 donut
# Speed: 31.8ms track, 0.7ms solution per image at shape (1, 3, 506, 898)
#
# 122: 506x898 0.6ms, 1 donut
# Speed: 32.4ms track, 0.6ms solution per image at shape (1, 3, 506, 898)
#
# 123: 506x898 0.8ms, 1 donut, 1 keyboard
# Speed: 30.9ms track, 0.8ms solution per image at shape (1, 3, 506, 898)
#
# 124: 506x898 0.7ms, 2 donut
# Speed: 31.8ms track, 0.7ms solution per image at shape (1, 3, 506, 898)
#
# 125: 506x898 1.0ms, 2 donut, 1 cake
# Speed: 31.7ms track, 1.0ms solution per image at shape (1, 3, 506, 898)
#
# 126: 506x898 0.8ms, 2 donut
# Speed: 32.9ms track, 0.8ms solution per image at shape (1, 3, 506, 898)
#
# 127: 506x898 1.1ms, 1 donut, 1 keyboard, 1 cake
# Speed: 32.3ms track, 1.1ms solution per image at shape (1, 3, 506, 898)
#
# 128: 506x898 1.1ms, 1 donut, 1 keyboard, 1 cake
# Speed: 32.3ms track, 1.1ms solution per image at shape (1, 3, 506, 898)
#
# 129: 506x898 1.7ms, 1 donut, 1 keyboard, 1 cake
# Speed: 44.6ms track, 1.7ms solution per image at shape (1, 3, 506, 898)
#
# 130: 506x898 0.6ms, 1 keyboard
# Speed: 33.8ms track, 0.6ms solution per image at shape (1, 3, 506, 898)
#
# WARNING ⚠️ no tracks found!
# 131: 506x898 1.3ms,
# Speed: 30.8ms track, 1.3ms solution per image at shape (1, 3, 506, 898)
#
# 132: 506x898 0.6ms, 1 cake
# Speed: 34.2ms track, 0.6ms solution per image at shape (1, 3, 506, 898)
#
# WARNING ⚠️ no tracks found!
# 133: 506x898 1.0ms,
# Speed: 32.9ms track, 1.0ms solution per image at shape (1, 3, 506, 898)
#
# 134: 506x898 0.6ms, 1 keyboard
# Speed: 33.2ms track, 0.6ms solution per image at shape (1, 3, 506, 898)
#
# 135: 506x898 1.3ms, 1 keyboard, 2 cake
# Speed: 33.2ms track, 1.3ms solution per image at shape (1, 3, 506, 898)
#
# 136: 506x898 0.6ms, 1 donut
# Speed: 33.3ms track, 0.6ms solution per image at shape (1, 3, 506, 898)
#
# 137: 506x898 0.8ms, 1 donut
# Speed: 32.5ms track, 0.8ms solution per image at shape (1, 3, 506, 898)
#
# 138: 506x898 1.1ms, 1 donut, 1 keyboard
# Speed: 32.3ms track, 1.1ms solution per image at shape (1, 3, 506, 898)
#
# 139: 506x898 0.9ms, 1 donut, 1 keyboard
# Speed: 38.4ms track, 0.9ms solution per image at shape (1, 3, 506, 898)
#
# 140: 506x898 0.6ms, 1 keyboard
# Speed: 34.3ms track, 0.6ms solution per image at shape (1, 3, 506, 898)
#
# 141: 506x898 0.6ms, 1 keyboard
# Speed: 33.1ms track, 0.6ms solution per image at shape (1, 3, 506, 898)
#
# WARNING ⚠️ no tracks found!
# 142: 506x898 1.3ms,
# Speed: 30.5ms track, 1.3ms solution per image at shape (1, 3, 506, 898)
#
# WARNING ⚠️ no tracks found!
# 143: 506x898 1.0ms,
# Speed: 30.3ms track, 1.0ms solution per image at shape (1, 3, 506, 898)
#
# 144: 506x898 0.7ms, 1 donut
# Speed: 32.5ms track, 0.7ms solution per image at shape (1, 3, 506, 898)
#
# 145: 506x898 0.9ms, 2 donut
# Speed: 36.0ms track, 0.9ms solution per image at shape (1, 3, 506, 898)
#
# 146: 506x898 0.8ms, 2 donut
# Speed: 32.4ms track, 0.8ms solution per image at shape (1, 3, 506, 898)
#
# 147: 506x898 0.8ms, 2 donut
# Speed: 32.4ms track, 0.8ms solution per image at shape (1, 3, 506, 898)
#
# 148: 506x898 0.8ms, 2 donut
# Speed: 31.4ms track, 0.8ms solution per image at shape (1, 3, 506, 898)
#
# WARNING ⚠️ no tracks found!
# 149: 506x898 0.9ms,
# Speed: 29.7ms track, 0.9ms solution per image at shape (1, 3, 506, 898)
#
# WARNING ⚠️ no tracks found!
# 150: 506x898 1.0ms,
# Speed: 30.8ms track, 1.0ms solution per image at shape (1, 3, 506, 898)
#
# 151: 506x898 0.8ms, 2 donut
# Speed: 31.0ms track, 0.8ms solution per image at shape (1, 3, 506, 898)
#
# 152: 506x898 0.6ms, 1 donut
# Speed: 31.8ms track, 0.6ms solution per image at shape (1, 3, 506, 898)
#
# WARNING ⚠️ no tracks found!
# 153: 506x898 1.0ms,
# Speed: 32.4ms track, 1.0ms solution per image at shape (1, 3, 506, 898)
#
# 154: 506x898 0.5ms, 1 donut
# Speed: 31.8ms track, 0.5ms solution per image at shape (1, 3, 506, 898)
#
# 155: 506x898 0.7ms, 1 donut
# Speed: 45.0ms track, 0.7ms solution per image at shape (1, 3, 506, 898)
#
# 156: 506x898 0.9ms, 3 donut
# Speed: 32.8ms track, 0.9ms solution per image at shape (1, 3, 506, 898)
#
# 157: 506x898 0.5ms, 1 donut
# Speed: 32.9ms track, 0.5ms solution per image at shape (1, 3, 506, 898)
#
# 158: 506x898 0.7ms, 2 donut
# Speed: 31.7ms track, 0.7ms solution per image at shape (1, 3, 506, 898)
#
#
ms track, 1.4ms solution per image at shape (1, 3, 506, 898)
#
# 201: 506x898 1.7ms, 5 donut
# Speed: 32.6ms track, 1.7ms solution per image at shape (1, 3, 506, 898)
#
# 202: 506x898 1.3ms, 5 donut
# Speed: 31.9ms track, 1.3ms solution per image at shape (1, 3, 506, 898)
#
# 203: 506x898 1.3ms, 5 donut
# Speed: 31.9ms track, 1.3ms solution per image at shape (1, 3, 506, 898)
#
# 204: 506x898 2.1ms, 7 donut, 1 keyboard
# Speed: 35.2ms track, 2.1ms solution per image at shape (1, 3, 506, 898)
#
# 205: 506x898 2.1ms, 7 donut, 1 keyboard
# Speed: 43.6ms track, 2.1ms solution per image at shape (1, 3, 506, 898)
#
# 206: 506x898 1.9ms, 7 donut, 1 keyboard
# Speed: 33.0ms track, 1.9ms solution per image at shape (1, 3, 506, 898)
#
# 207: 506x898 1.7ms, 7 donut
# Speed: 33.2ms track, 1.7ms solution per image at shape (1, 3, 506, 898)
#
# 208: 506x898 2.1ms, 9 donut, 1 keyboard
# Speed: 32.8ms track, 2.1ms solution per image at shape (1, 3, 506, 898)
#
# 209: 506x898 2.3ms, 9 donut, 1 keyboard
# Speed: 33.3ms track, 2.3ms solution per image at shape (1, 3, 506, 898)
#
# 210: 506x898 2.2ms, 9 donut, 1 keyboard
# Speed: 33.3ms track, 2.2ms solution per image at shape (1, 3, 506, 898)
#
# 211: 506x898 2.0ms, 9 donut
# Speed: 33.3ms track, 2.0ms solution per image at shape (1, 3, 506, 898)
#
# 212: 506x898 2.1ms, 10 donut
# Speed: 33.2ms track, 2.1ms solution per image at shape (1, 3, 506, 898)
#
# 213: 506x898 2.0ms, 9 donut
# Speed: 36.0ms track, 2.0ms solution per image at shape (1, 3, 506, 898)
#
# 214: 506x898 1.8ms, 8 donut
# Speed: 33.5ms track, 1.8ms solution per image at shape (1, 3, 506, 898)
#
# 215: 506x898 2.2ms, 9 donut
# Speed: 33.1ms track, 2.2ms solution per image at shape (1, 3, 506, 898)
#
# 216: 506x898 1.8ms, 8 donut
# Speed: 32.9ms track, 1.8ms solution per image at shape (1, 3, 506, 898)
#
# 217: 506x898 1.7ms, 8 donut
# Speed: 33.6ms track, 1.7ms solution per image at shape (1, 3, 506, 898)
#
# 218: 506x898 1.5ms, 6 donut
# Speed: 33.9ms track, 1.5ms solution per image at shape (1, 3, 506, 898)
#
# 219: 506x898 1.2ms, 5 donut
# Speed: 33.1ms track, 1.2ms solution per image at shape (1, 3, 506, 898)
#
# 220: 506x898 1.1ms, 5 donut
# Speed: 31.9ms track, 1.1ms solution per image at shape (1, 3, 506, 898)
#
# 221: 506x898 1.6ms, 7 donut
# Speed: 34.0ms track, 1.6ms solution per image at shape (1, 3, 506, 898)
#
# 222: 506x898 1.7ms, 8 donut
# Speed: 33.5ms track, 1.7ms solution per image at shape (1, 3, 506, 898)
#
# 223: 506x898 1.9ms, 8 donut, 1 cake
# Speed: 32.5ms track, 1.9ms solution per image at shape (1, 3, 506, 898)
#
# 224: 506x898 2.1ms, 9 donut, 1 cake
# Speed: 33.0ms track, 2.1ms solution per image at shape (1, 3, 506, 898)
#
# 225: 506x898 2.2ms, 9 donut, 1 cake
# Speed: 33.1ms track, 2.2ms solution per image at shape (1, 3, 506, 898)
#
# 226: 506x898 1.8ms, 7 donut, 1 cake
# Speed: 32.5ms track, 1.8ms solution per image at shape (1, 3, 506, 898)
#
# 227: 506x898 2.0ms, 6 donut, 2 cake
# Speed: 32.9ms track, 2.0ms solution per image at shape (1, 3, 506, 898)
#
# 228: 506x898 2.2ms, 5 cake, 5 donut
# Speed: 34.6ms track, 2.2ms solution per image at shape (1, 3, 506, 898)
#
# 229: 506x898 3.3ms, 7 cake, 1 donut
# Speed: 47.6ms track, 3.3ms solution per image at shape (1, 3, 506, 898)
#
# 230: 506x898 1.5ms, 2 donut, 5 cake
# Speed: 33.6ms track, 1.5ms solution per image at shape (1, 3, 506, 898)
#
# 231: 506x898 1.7ms, 1 donut, 8 cake
# Speed: 32.6ms track, 1.7ms solution per image at shape (1, 3, 506, 898)
#
# 232: 506x898 1.5ms, 4 donut, 3 cake
# Speed: 32.9ms track, 1.5ms solution per image at shape (1, 3, 506, 898)
#
# 233: 506x898 1.6ms, 4 donut, 3 cake
# Speed: 32.8ms track, 1.6ms solution per image at shape (1, 3, 506, 898)
#
# 234: 506x898 1.6ms, 6 cake, 1 donut
# Speed: 33.6ms track, 1.6ms solution per image at shape (1, 3, 506, 898)
#
# 235: 506x898 2.0ms, 9 donut
# Speed: 32.5ms track, 2.0ms solution per image at shape (1, 3, 506, 898)
#
# 236: 506x898 2.7ms, 11 donut
# Speed: 32.4ms track, 2.7ms solution per image at shape (1, 3, 506, 898)
#
# 237: 506x898 2.3ms, 12 donut
# Speed: 35.6ms track, 2.3ms solution per image at shape (1, 3, 506, 898)
#
# 238: 506x898 2.4ms, 12 donut
# Speed: 32.4ms track, 2.4ms solution per image at shape (1, 3, 506, 898)
#
# 239: 506x898 2.6ms, 12 donut
# Speed: 32.8ms track, 2.6ms solution per image at shape (1, 3, 506, 898)
#
# 240: 506x898 2.0ms, 9 donut
# Speed: 33.4ms track, 2.0ms solution per image at shape (1, 3, 506, 898)
#
# 241: 506x898 1.4ms, 7 donut
# Speed: 32.6ms track, 1.4ms solution per image at shape (1, 3, 506, 898)
#
# 242: 506x898 2.1ms, 10 donut
# Speed: 34.2ms track, 2.1ms solution per image at shape (1, 3, 506, 898)
#
# 243: 506x898 1.4ms, 7 donut
# Speed: 32.6ms track, 1.4ms solution per image at shape (1, 3, 506, 898)
#
# 244: 506x898 1.6ms, 8 donut
# Speed: 32.8ms track, 1.6ms solution per image at shape (1, 3, 506, 898)
#
# 245: 506x898 2.0ms, 8 donut, 1 cake
# Speed: 32.6ms track, 2.0ms solution per image at shape (1, 3, 506, 898)
#
# 246: 506x898 2.0ms, 2 cake, 6 donut
# Speed: 37.7ms track, 2.0ms solution per image at shape (1, 3, 506, 898)
#
# 247: 506x898 2.3ms, 8 donut, 1 keyboard
# Speed: 38.3ms track, 2.3ms solution per image at shape (1, 3, 506, 898)
#
# 248: 506x898 2.2ms, 8 donut, 1 keyboard
# Speed: 36.6ms track, 2.2ms solution per image at shape (1, 3, 506, 898)
#
# 249: 506x898 1.9ms, 1 cake, 6 donut, 1 keyboard
# Speed: 36.3ms track, 1.9ms solution per image at shape (1, 3, 506, 898)
#
# 250: 506x898 1.6ms, 6 donut, 1 keyboard
# Speed: 34.1ms track, 1.6ms solution per image at shape (1, 3, 506, 898)
#
# 251: 506x898 1.2ms, 3 donut, 1 keyboard
# Speed: 34.4ms track, 1.2ms solution per image at shape (1, 3, 506, 898)
#
# 252: 506x898 1.3ms, 4 donut, 1 keyboard
# Speed: 32.2ms track, 1.3ms solution per image at shape (1, 3, 506, 898)
#
# 253: 506x898 3.0ms, 5 donut, 1 keyboard, 1 cake
# Speed: 46.3ms track, 3.0ms solution per image at shape (1, 3, 506, 898)
#
# 254: 506x898 1.0ms, 2 donut, 1 keyboard
# Speed: 31.7ms track, 1.0ms solution per image at shape (1, 3, 506, 898)
#
# 255: 506x898 0.8ms, 1 donut, 1 cake
# Speed: 31.1ms track, 0.8ms solution per image at shape (1, 3, 506, 898)
#
# 256: 506x898 1.2ms, 3 donut, 1 cake
# Speed: 30.3ms track, 1.2ms solution per image at shape (1, 3, 506, 898)
#
# 257: 506x898 1.3ms, 2 donut, 1 cake, 1 keyboard
# Speed: 30.6ms track, 1.3ms solution per image at shape (1, 3, 506, 898)
#
# 258: 506x898 0.8ms, 1 keyboard, 1 cake
# Speed: 30.4ms track, 0.8ms solution per image at shape (1, 3, 506, 898)
#
# Video frame is empty or video processing has been successfully completed.
# <PIL.Image.Image image mode=RGB size=898x506>
# <PIL.Image.Image image mode=RGB size=898x506>

# %%
from collections import defaultdict

import cv2
import numpy as np

from ultralytics import YOLO

model = YOLO("yolo11n.pt")
video_path = "/content/3669014919-preview.mp4"
cap = cv2.VideoCapture(video_path)
track_history = defaultdict(lambda: [])

while cap.isOpened():
    success, frame = cap.read()
    if success:
        results = model.track(frame, persist=True)
        boxes = results[0].boxes.xywh.cpu()
        track_ids = results[0].boxes.id.int().cpu().tolist()
        annotated_frame = results[0].plot()
        for box, track_id in zip(boxes, track_ids):
            x, y, w, h = box
            track = track_history[track_id]
            track.append((float(x), float(y)))
            if len(track) > 30:
                track.pop(0)
            points = np.hstack(track).astype(np.int32).reshape((-1, 1, 2))
            cv2.polylines(annotated_frame, [points], isClosed=False, color=(230, 230, 230), thickness=10)
        cv2.imshow("YOLO11 Tracking", annotated_frame)
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    else:
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 10 donuts, 8.3ms
# Speed: 1.8ms preprocess, 8.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# ---------------------------------------------------------------------------
# DisabledFunctionError                     Traceback (most recent call last)
# /tmp/ipython-input-1389793194.py in <cell line: 0>()
#      26             points = np.hstack(track).astype(np.int32).reshape((-1, 1, 2))
#      27             cv2.polylines(annotated_frame, [points], isClosed=False, color=(230, 230, 230), thickness=10)
# ---> 28         cv2.imshow("YOLO11 Tracking", annotated_frame)
#      29         if cv2.waitKey(1) & 0xFF == ord("q"):
#      30             break
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_import_hooks/_cv2.py in wrapped(*args, **kwargs)
#      48   def wrapped(*args, **kwargs):
#      49     if not os.environ.get(env_var, False):
# ---> 50       raise DisabledFunctionError(message, name or func.__name__)
#      51     return func(*args, **kwargs)
#      52
#
# DisabledFunctionError: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow

# %%
from ultralytics import YOLO

# Load a pretrained YOLO11n model
model = YOLO("yolo11n.pt")

# Train the model on the COCO8 dataset for 100 epochs
train_results = model.train(
    data="coco8.yaml",  # Path to dataset configuration file
    epochs=100,  # Number of training epochs
    imgsz=640,  # Image size for training
    device="gpu",  # Device to run on (e.g., 'cpu', 0, [0,1,2,3])
)

# Evaluate the model's performance on the validation set
metrics = model.val()
# Out:
# Ultralytics 8.3.232 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:gpu (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=coco8.yaml, degrees=0.0, deterministic=True, device=gpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train2, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/content/runs/detect/train2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    464912  ultralytics.nn.modules.head.Detect           [80, [64, 128, 256]]
# YOLO11n summary: 181 layers, 2,624,080 parameters, 2,624,064 gradients, 6.6 GFLOPs
#
# Transferred 499/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1659.0±574.6 MB/s, size: 50.0 KB)
# train: Scanning /content/datasets/coco8/labels/train.cache... 4 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4/4 6.3Kit/s 0.0s
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 337.6±82.8 MB/s, size: 54.0 KB)
# val: Scanning /content/datasets/coco8/labels/val.cache... 4 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4/4 3.0Kit/s 0.0s
# Plotting labels to /content/runs/detect/train2/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000119, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /content/runs/detect/train2
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100     0.645G     0.9078       2.63      1.334         29        640: 100% ━━━━━━━━━━━━ 1/1 10.6s/it 10.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.8s/it 3.8s
#                    all          4         17      0.592       0.85      0.878      0.634
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100     0.674G      1.328      3.181      1.625         46        640: 100% ━━━━━━━━━━━━ 1/1 5.6it/s 0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 7.5it/s 0.1s
#                    all          4         17      0.584       0.85      0.847      0.631
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100     0.674G     0.9821      3.036      1.326         20        640: 100% ━━━━━━━━━━━━ 1/1 5.9it/s 0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 7.8it/s 0.1s
#                    all          4         17      0.587       0.85      0.851      0.615
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100     0.674G      1.283      3.208      1.582         35        640: 100% ━━━━━━━━━━━━ 1/1 4.7it/s 0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 15.6it/s 0.1s
#                    all          4         17      0.631      0.922      0.905       0.64
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100     0.674G      1.166      3.551       1.57         15        640: 100% ━━━━━━━━━━━━ 1/1 4.8it/s 0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 12.8it/s 0.1s
#                    all          4         17      0.589       0.85      0.874      0.637
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100     0.674G      1.018       3.24      1.372         31        640: 100% ━━━━━━━━━━━━ 1/1 4.0it/s 0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 19.8it/s 0.1s
#                    all          4         17      0.607       0.85      0.859      0.636
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100     0.705G      1.287      2.921      1.586         35        640: 100% ━━━━━━━━━━━━ 1/1 7.0it/s 0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 16.7it/s 0.1s
#                    all          4         17      0.589       0.85       0.86      0.627
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100     0.721G      1.142      2.681       1.43         34        640: 100% ━━━━━━━━━━━━ 1/1 7.1it/s 0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 18.8it/s 0.1s
#                    all          4         17      0.565      0.851      0.861      0.628
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100     0.736G      1.243      2.867      1.521         40        640: 100% ━━━━━━━━━━━━ 1/1 7.5it/s 0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 19.5it/s 0.1s
#                    all          4         17      0.588      0.867      0.897      0.617
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      0.75G     0.9301      2.637      1.218         30        640: 100% ━━━━━━━━━━━━ 1/1 7.4it/s 0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 19.2it/s 0.1s
#                    all          4         17      0.573      0.867      0.896      0.615
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      0.75G      1.021      2.148      1.356         18        640: 100% ━━━━━━━━━━━━ 1/1 7.2it/s 0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 20.0it/s 0.0s
#                    all          4         17       0.55      0.867      0.897      0.629
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100     0.754G      1.133      2.139      1.474         17        640: 100% ━━━━━━━━━━━━ 1/1 7.2it/s 0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 19.5it/s 0.1s
#                    all          4         17      0.568      0.867      0.897      0.622
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100     0.754G     0.8336      2.392      1.226         28        640: 100% ━━━━━━━━━━━━ 1/1 7.5it/s 0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 19.2it/s 0.1s
#                    all          4         17      0.632      0.939      0.912      0.642
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100     0.768G      0.996      2.339      1.315         43        640: 100% ━━━━━━━━━━━━ 1/1 7.5it/s 0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 15.9it/s 0.1s
#                    all          4         17      0.629       0.95      0.911      0.647
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100     0.768G     0.8715      2.323      1.269         32        640: 100% ━━━━━━━━━━━━ 1/1 7.6it/s 0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 19.4it/s 0.1s
#                    all          4         17      0.641       0.95      0.912      0.647
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100     0.768G      1.077      1.964       1.61         26        640: 100% ━━━━━━━━━━━━ 1/1 7.4it/s 0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 20.0it/s 0.0s
#                    all          4         17      0.642       0.95      0.912       0.65
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100     0.768G     0.9656      1.174      1.192         28        640: 100% ━━━━━━━━━━━━ 1/1 7.2it/s 0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 19.0it/s 0.1s
#                    all          4         17      0.634       0.95      0.912       0.64
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100     0.768G     0.7792      2.622      1.375         19        640: 100% ━━━━━━━━━━━━ 1/1 9.8it/s 0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 15.2it/s 0.1s
#                    all          4         17      0.634       0.95      0.912       0.64
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100     0.768G      1.046      2.765      1.386         19        640: 100% ━━━━━━━━━━━━ 1/1 7.7it/s 0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 20.0it/s 0.1s
#                    all          4         17      0.636       0.95      0.913      0.639
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100     0.768G     0.9698      1.785      1.409         23        640: 100% ━━━━━━━━━━━━ 1/1 9.5it/s 0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 20.0it/s 0.0s
#                    all          4         17      0.636       0.95      0.913      0.639
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100      0.77G      1.254      2.328      1.452         34        640: 100% ━━━━━━━━━━━━ 1/1 7.6it/s 0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 18.6it/s 0.1s
#                    all          4         17      0.648       0.95      0.911      0.636
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/100      0.77G      1.161      2.616      1.387         40        640: 100% ━━━━━━━━━━━━ 1/1 10.0it/s 0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 19.7it/s 0.1s
#                    all          4         17      0.648       0.95      0.911      0.636
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/100     0.791G       1.01      1.659      1.236         34        640: 100% ━━━━━━━━━━━━ 1/1 7.2it/s 0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 19.8it/s 0.1s
#                    all          4         17      0.844       0.65      0.856      0.617
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/100     0.797G     0.9722      2.013      1.245         51        640: 100% ━━━━━━━━━━━━ 1/1 8.7it/s 0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 19.4it/s 0.1s
#                    all          4         17      0.844       0.65      0.856      0.617
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/100
0.298
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/100     0.836G     0.7278     0.6637      1.107         29        640: 100% ━━━━━━━━━━━━ 1/1 9.0it/s 0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 19.8it/s 0.1s
#                    all          4         17      0.809        0.5      0.507      0.298
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/100     0.836G     0.7556     0.7891      1.147         34        640: 100% ━━━━━━━━━━━━ 1/1 3.0it/s 0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 19.9it/s 0.1s
#                    all          4         17      0.807        0.5      0.506      0.297
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/100     0.836G     0.7723     0.7608      1.088         47        640: 100% ━━━━━━━━━━━━ 1/1 9.3it/s 0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 18.5it/s 0.1s
#                    all          4         17      0.807        0.5      0.506      0.297
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/100     0.836G     0.7584     0.8773      1.252         13        640: 100% ━━━━━━━━━━━━ 1/1 9.6it/s 0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 19.2it/s 0.1s
#                    all          4         17      0.807        0.5      0.506      0.297
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100     0.836G     0.4629      0.434     0.9012         13        640: 100% ━━━━━━━━━━━━ 1/1 2.6it/s 0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 12.1it/s 0.1s
#                    all          4         17      0.807        0.5      0.506      0.297
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100     0.836G     0.5969     0.6611      1.025         13        640: 100% ━━━━━━━━━━━━ 1/1 7.3it/s 0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 13.5it/s 0.1s
#                    all          4         17      0.795        0.5      0.505      0.283
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100     0.836G     0.5187     0.4778     0.9622         13        640: 100% ━━━━━━━━━━━━ 1/1 8.3it/s 0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 14.1it/s 0.1s
#                    all          4         17      0.795        0.5      0.505      0.283
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100     0.836G     0.4843     0.4966     0.9017         13        640: 100% ━━━━━━━━━━━━ 1/1 9.5it/s 0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 15.3it/s 0.1s
#                    all          4         17      0.795        0.5      0.505      0.283
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100     0.836G      0.629     0.5496      1.064         13        640: 100% ━━━━━━━━━━━━ 1/1 6.4it/s 0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 13.5it/s 0.1s
#                    all          4         17      0.795        0.5      0.505      0.283
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100     0.836G     0.5559      0.504     0.9911         13        640: 100% ━━━━━━━━━━━━ 1/1 5.7it/s 0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 13.5it/s 0.1s
#                    all          4         17      0.627      0.499      0.506      0.295
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100     0.836G     0.6513     0.6079      1.111         13        640: 100% ━━━━━━━━━━━━ 1/1 6.8it/s 0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 10.8it/s 0.1s
#                    all          4         17      0.627      0.499      0.506      0.295
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100     0.836G     0.5676      0.531     0.9393         13        640: 100% ━━━━━━━━━━━━ 1/1 8.5it/s 0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 15.4it/s 0.1s
#                    all          4         17      0.627      0.499      0.506      0.295
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100     0.836G     0.6595     0.5601      1.006         13        640: 100% ━━━━━━━━━━━━ 1/1 8.9it/s 0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 18.9it/s 0.1s
#                    all          4         17      0.627      0.499      0.506      0.295
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100     0.836G     0.5802     0.5779      1.024         13        640: 100% ━━━━━━━━━━━━ 1/1 7.5it/s 0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 18.8it/s 0.1s
#                    all          4         17      0.627      0.497      0.519      0.324
#
# 100 epochs completed in 0.019 hours.
# Optimizer stripped from /content/runs/detect/train2/weights/last.pt, 5.5MB
# Optimizer stripped from /content/runs/detect/train2/weights/best.pt, 5.5MB
#
# Validating /content/runs/detect/train2/weights/best.pt...
# Ultralytics 8.3.232 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:gpu (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 100 layers, 2,616,248 parameters, 0 gradients, 6.5 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 20.2it/s 0.0s
#                    all          4         17      0.642       0.95      0.913       0.65
#                 person          3         10      0.641        0.7      0.667       0.34
#                    dog          1          1      0.535          1      0.995      0.796
#                  horse          1          2      0.673          1      0.995       0.65
#               elephant          1          2      0.547          1      0.828      0.322
#               umbrella          1          1      0.558          1      0.995      0.895
#           potted plant          1          1      0.895          1      0.995      0.895
# Speed: 0.3ms preprocess, 5.5ms inference, 0.0ms loss, 1.8ms postprocess per image
# Results saved to /content/runs/detect/train2
# Ultralytics 8.3.232 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 100 layers, 2,616,248 parameters, 0 gradients, 6.5 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1119.9±677.2 MB/s, size: 54.0 KB)
# val: Scanning /content/datasets/coco8/labels/val.cache... 4 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4/4 5.1Kit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.2it/s 0.2s
#                    all          4         17      0.643       0.95      0.914      0.651
#                 person          3         10      0.642        0.7      0.673      0.344
#                    dog          1          1      0.532          1      0.995      0.796
#                  horse          1          2      0.673          1      0.995       0.65
#               elephant          1          2      0.549          1      0.828      0.322
#               umbrella          1          1      0.558          1      0.995      0.895
#           potted plant          1          1      0.904          1      0.995      0.895
# Speed: 2.1ms preprocess, 26.2ms inference, 0.0ms loss, 1.3ms postprocess per image
# Results saved to /content/runs/detect/val

# %%
# Perform object detection on an image
results = model("/content/download.png")  # Predict on an image
results[0].show()  # Display results

# Export the model to ONNX format for deployment
path = model.export(format="onnx")  # Returns the path to the exported model
# Out:
# image 1/1 /content/download.png: 448x640 1 bus, 48.7ms
# Speed: 1.8ms preprocess, 48.7ms inference, 1.4ms postprocess per image at shape (1, 3, 448, 640)
# <PIL.Image.Image image mode=RGB size=212x148>
# Ultralytics 8.3.232 🚀 Python-3.12.12 torch-2.9.0+cu126 CPU (Intel Xeon CPU @ 2.20GHz)
# 💡 ProTip: Export to OpenVINO format for best performance on Intel hardware. Learn more at https://docs.ultralytics.com/integrations/openvino/
#
# PyTorch: starting from '/content/runs/detect/train2/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 84, 8400) (5.3 MB)
# requirements: Ultralytics requirements ['onnx>=1.12.0,<=1.19.1', 'onnxslim>=0.1.71', 'onnxruntime-gpu'] not found, attempting AutoUpdate...
# Using Python 3.12.12 environment at: /usr
# Resolved 14 packages in 120ms
# Prepared 6 packages in 6.82s
# Installed 6 packages in 237ms
#  + colorama==0.4.6
#  + coloredlogs==15.0.1
#  + humanfriendly==10.0
#  + onnx==1.19.1
#  + onnxruntime-gpu==1.23.2
#  + onnxslim==0.1.77
#
# requirements: AutoUpdate success ✅ 7.4s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
#
# ONNX: starting export with onnx 1.19.1 opset 22...
# ONNX: slimming with onnxslim 0.1.77...
# ONNX: export success ✅ 8.9s, saved as '/content/runs/detect/train2/weights/best.onnx' (10.2 MB)
#
# Export complete (9.3s)
# Results saved to /content/runs/detect/train2/weights
# Predict:         yolo predict task=detect model=/content/runs/detect/train2/weights/best.onnx imgsz=640
# Validate:        yolo val task=detect model=/content/runs/detect/train2/weights/best.onnx imgsz=640 data=/usr/local/lib/python3.12/dist-packages/ultralytics/cfg/datasets/coco8.yaml
# Visualize:       https://netron.app
